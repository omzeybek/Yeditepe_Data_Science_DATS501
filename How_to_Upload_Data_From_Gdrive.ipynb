# %% [markdown]
# <a href="https://colab.research.google.com/github/omzeybek/Yeditepe_Data_Science_DATS501/blob/main/How_to_Upload_Data_From_Gdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loading Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# !ls "/content/drive/My Drive/02_DATS511/01_Data/"
# Out:
#  bank.csv	    CPI_2025.gsheet   Prod.csv
# 'book_read 2.csv'   CPI.csv	      SBAcase.csv
#  book_read.csv	    CPI.gsheet	      SEAS.csv
#  covid-data.csv     LT_IND_PRO.csv    synthetic_wage_education_data_n45.csv
#  CPI_2025.csv	    LT_IND_PRO.xlsx  'Week13 - TimeSeriesRegression.ipynb'

# %%
import pandas as pd

file_path = "/content/drive/My Drive/02_DATS511/01_Data/CPI_2025.csv"
df = pd.read_csv(file_path, sep=';')  # Noktalı virgül önemli!
df.head()
# Out:
#     Month CPI_MoM_Pct
# 0  Jan.20        1,35
# 1  Feb.20        0,35
# 2  Mar.20        0,57
# 3  Apr.20        0,85
# 4  May.20        1,36
